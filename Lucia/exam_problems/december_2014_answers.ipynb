# %% [markdown]
# # **Exam 9. December 2014**

# %% [markdown]
# ### **Question 1.1**
#
# <img src="SymPyBilleder/2025-11-16-10-56-21.png" width="550">
#
# <img src="SymPyBilleder/2025-11-16-10-56-43.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# We know that maximum likelihood estimator is:
# $$
# \hat{\theta} = (X^TX)^{-1}X^Ty
# $$
# So we have to calculate:
# $$
# \hat{\theta} = \begin{bmatrix} 5 & 0 & 0 \\ 0 & 10 & 0 \\ 0 & 0 & 14 \end{bmatrix}^{-1}\begin{bmatrix} 1 & -2 & 2 \\ 1 & -1 & -1 \\ 1 & 0 & -2 \\ 1 & 1 & -1 \\ 1 & 2 & 2 \end{bmatrix}^T \begin{bmatrix} 2 \\ 1 \\ 3 \\ 4 \\ 0 \end{bmatrix}
# $$
# We only take the first column of the observation matrix, since we only want to find the estimator for $X$. This is calculated in R.

# %%
xx = matrix(c(5,0,0,0,10,0,0,0,14), nrow=3, byrow=TRUE)
X = matrix(c(1,1,1,1,1, -2,-1,0,1,2, 2,-1,-2,-1,2), nrow=5, byrow=FALSE)
y = matrix(c(2,1,3,4,0), nrow=5, byrow=FALSE)

theta_hat = solve(xx) %*% t(X) %*% y
theta_hat
# Out:
#      [,1]
# [1,]  2.0
# [2,] -0.1
# [3,] -0.5

# %% [markdown]
# We just have to pick the first entry, because that corresponds to $\alpha_x$.
#
# **The answer is, therefore, option 2.**

# %% [markdown]
# ### **Question 1.2**
#
# <img src="SymPyBilleder/2025-11-16-11-22-57.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# We just use:
# $$
# V(\hat{\beta}) = \sigma^2 (X^TX)^{-1}
# $$
# We get:
# $$
# = \sigma^2 \begin{bmatrix} 5 & 0 & 0 \\ 0 & 10 & 0 \\ 0 & 0 & 14 \end{bmatrix}^{-1}
# $$
# $$
# = \sigma^2 \begin{bmatrix} \frac{1}{5} & 0 & 0 \\ 0 & \frac{1}{10} & 0 \\ 0 & 0 & \frac{1}{14} \end{bmatrix}
# $$
# So between $\alpha_x$ and $\beta_x$ is is the entry in second row and first column.
#
# **The answer is, therefore, option 2.**

# %% [markdown]
# ### **Question 1.3**
#
# <img src="SymPyBilleder/2025-11-16-11-42-48.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# Now, we because we have different responses one from $x$ another from $y$, we have to calculate like this:
# $$
# Cov(\alpha_x, \alpha_y) = \sigma_{xy} (X^TX)^{-1}
# $$
# HERE our \sigma_{xy} is NOT to the power of $2$ because we read it directly from our $\Sigma$ matrix, we get:
# $$
# = \sigma_{xy} \begin{bmatrix} 5 & 0 & 0 \\ 0 & 10 & 0 \\ 0 & 0 & 14 \end{bmatrix}^{-1}
# $$
# $$
# = \sigma_{xy} \begin{bmatrix} \frac{1}{5} & 0 & 0 \\ 0 & \frac{1}{10} & 0 \\ 0 & 0 & \frac{1}{14} \end{bmatrix}
# $$
# We choose element $(1,1)$ because we want covariance between $\alpha_x$ and $\alpha_y$ both being the first parameters so $\sigma_{xy} \frac{1}{5}$.
#
# **The answer is, therefore, option 3.**

# %% [markdown]
# ### **Question 1.4**
#
# <img src="SymPyBilleder/2025-11-16-12-16-27.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# We need the four parameters in the hypothesis to equal $0$ but to get those, we need the $\beta$ and $\gamma$ parameters. Only option $4$ allows us to do that, because the matrix multiplication keeps row 2 and 3.
#
# **The answer is, therefore, option 4.**

# %% [markdown]
# ### **Question 1.5**
#
# <img src="SymPyBilleder/2025-11-16-12-28-22.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# After multiplying with $A$ we end up with:
# $$
# \begin{bmatrix} \beta_x & \beta_y & \beta_z \\ \gamma_x & \gamma_y & \gamma_z \end{bmatrix}
# $$
# SO to only have the last four parameters equal to $0$ AND we remember that $B'$ is multiplied from the left, so we have to pick a matrix that has $3$ columns, we we have to choose option 2 because:
# $$
# \begin{bmatrix} 0 & 1 & 0 \\ 0 & 0 & 1 \end{bmatrix}^T = \begin{bmatrix} 0 & 0 \\ 1 & 0 \\ 0 & 1 \end{bmatrix}
# $$
# **The answer is, therefore, option 2.**

# %% [markdown]
# ### **Question 1.6**
#
# <img src="SymPyBilleder/2025-11-16-12-37-06.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# CHAT GOT THIS ONE WRONG AND DID NOT HELP CORRECTLY.
#
# WE have to use Theorem 4.2 (from an old book idk which one) given as:
# $$
# U(r, s, n-p)
# $$
# Here, $r$ is the number of linear constraints, $s$ is number of responses involved and $n$ is number of observations and $p$ is number of parameters. First, from $A$ we limit to only beta and gamma so $r=2$, then $s$ we only have $2$ responses (beta and gamma), $n=5$ observations and $p=3$ parameters (alpha, beta and gamma). So we get:
# $$
# U(2, 2, 5-3) = U(2, 2, 2)
# $$
# **The answer is, therefore, option 4.**

# %% [markdown]
# ### **Question 2.1**
#
# <img src="SymPyBilleder/2025-11-16-12-52-01.png" width="550">
#
# <img src="SymPyBilleder/2025-11-16-12-52-12.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# We have to use the formula for computing discriminant direction:
# $$
# \Sigma^{-1}(\mu_1 - \mu_2)
# $$
# Inserting our values from the task description we get:
# $$
# \begin{bmatrix} \frac{4}{3} & -\frac{2}{3} \\ -\frac{2}{3} & \frac{4}{3} \end{bmatrix} \begin{bmatrix} -3\\ -3 \end{bmatrix} =  \begin{bmatrix} -2 \\ -2 \end{bmatrix}
# $$
# So we have:
# $$
# Z = -2X-2Y + \text{constant}
# $$
# General formula for constant WHEN PRIOS ARE EQUAL:
# $$
# c = - \frac{1}{2} \mu_1^T \Sigma^{-1} \mu_1 + \frac{1}{2} \mu_2^T \Sigma^{-1} \mu_2
# $$
# Given values from above this is:
# $$
# c = -\frac{1}{2} \cdot \frac{4}{3} + \frac{1}{2} \cdot \frac{64}{3}
# $$
# Calculate below.

# %%
-1/2*4/3+1/2*64/3
# Out:
# 10.0

# %% [markdown]
# (NOTE the signs or addition order in $c$ formula can be switched, the goal is to have $Z(x) > 0$).
#
# **The answer is, therefore, option 2.**

# %% [markdown]
# ### **Question 2.2**
#
# <img src="SymPyBilleder/2025-11-16-13-54-14.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# We have:
# $$
# Z = -2X-2Y+10
# $$
# So the mean:
# $$
# E(Z) = -2E(X) - 2E(Y) + 10
# $$
# $$
# = -2 \cdot 4 - 2 \cdot 4 + 10 = -6
# $$
# Because when $\pi_2$ is true then $E\left( \begin{bmatrix} X \\ X \end{bmatrix} \right) = \begin{bmatrix} 4 \\ 4 \end{bmatrix}$.
#
# **The answer is, therefore, option 1.**

# %% [markdown]
# ### **Question 2.3**
#
# <img src="SymPyBilleder/2025-11-16-13-59-14.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# We do:
# $$
# V(Z) = V(-2X-2Y+10)
# $$
# $$
# = 4V(X) + 4V(Y) + 2 \cdot (-2) \cdot (-2) \cdot Cov(X,Y)
# $$
# From the $Z$ matrix we can see the variances ad covarance:
# $$
# = 4 \cdot 1 + 4 \cdot 1 + 8 \cdot \frac{1}{2} = 4 + 4 + 4 = 12
# $$
# **The answer is, therefore, option 4.**

# %% [markdown]
# ### **Question 2.4**
#
# <img src="SymPyBilleder/2025-11-16-14-05-20.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# WE compute missclasification probability via:
# $$
# P(Z > 0 | \pi_2) = P\left( \frac{Z - E(Z)}{\sqrt{V(Z)}} > \frac{0 - (-6)}{\sqrt{12}} \right) = P\left( Z^* > \frac{6}{2\sqrt{3}} \right)
# $$
# $$
# =  P\left( \frac{Z +6}{\sqrt{12}} > \frac{0 + 6}{\sqrt{12}} \right)
# $$
# $$
# = P\left( Z > \frac{6}{\sqrt{12}} \right)
# $$
# $$
# = 1 - \Phi\left( \frac{6}{\sqrt{12}} \right)
# $$
# Here we have to simplify $\frac{6}{\sqrt{12}}$:
# $$
# = \frac{6}{2\sqrt{3}} = \frac{3}{\sqrt{3}} = \sqrt{3}
# $$
# **The answer is, therefore, option 3.**

# %% [markdown]
# ### **Question 2.5**
#
# <img src="SymPyBilleder/2025-11-16-14-18-12.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# Now that we have a prior probability then:
# $$
# c = -\frac{1}{2} \mu_1^T \Sigma^{-1} \mu_1 + \frac{1}{2} \mu_2^T \Sigma^{-1} \mu_2
# $$
# Must have:
# $$
# \log{\frac{\pi_1}{\pi_2}}
# $$
# Because we no longer have equal priors. But now:
# $$
# \log{\frac{0.1}{0.9}} = -2.19
# $$
# So now mean is:
# $$
# E(Z) = -2 \cdot 4 - 2 \cdot 4 + 10 - 2.19 = -8.19
# $$
# Variance is still $12$:
# $$
# V(Z) = (-2)^2 \cdot 1 + (-2)^2 \cdot 1 + 2 \cdot (-2) \cdot (-2) \cdot \frac{1}{2} = 12
# $$
# So now:
# $$
# \Phi\left( \frac{0-(-8.19)}{\sqrt{12}}\right) = \Phi\left( \frac{8.19}{\sqrt{12}}\right)
# $$
# $$
# = \Phi(2.36)
# $$
# So the answer is like $1-\Phi(2.36)$.
#
# **The answer is, therefore, option 2.**

# %% [markdown]
# ### **Question 3.1**
#
# <img src="SymPyBilleder/2025-11-16-14-29-38.png" width="550">
#
# <img src="SymPyBilleder/2025-11-16-14-30-00.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# WE use:
#
# Formula:
# $$
# [u+t(n-k)_{1-\frac{\alpha}{2}}s\sqrt{c}, u+t(n-k)_{\frac{\alpha}{2}}s\sqrt{c}]
# $$
# Here, $u$ is the predicted value, $n$ is the number of observations and $k$ is the number of parameters (with intercept), $t(n-k)_{1-\frac{\alpha}{2}}$ is the $t$-value for the confidence level, $s$ is the estimated standard deviation of the residuals, and $c$ is given by:
# $$
# c = x_0^T (X^TX)^{-1} x_0
# $$
# Moreover, for instance, if we have $95\%$ confidence interval, then $\alpha = 0.05$ so inside R function we write `qt(0.975, df=n-k)` because $1-\frac{\alpha}{2} = 0.975$.
#
# SO:
#
# We have $n=20$ and $k=2$ intercepts, hence $t(18)$ and level is $1-0.05/2=0.975$ then $s = 0.03336$ (NOT SQUARED IN OUTPUT).
#
# **The answer is, therefore, option 1.**

# %% [markdown]
# ### **Question 3.2**
#
# <img src="SymPyBilleder/2025-11-17-10-50-13.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# We use this formula:
# $$
# \hat{y} \pm t s \sqrt{1 + x_0^T (X^T X)^{-1} x_0}
# $$
# MEANWHILE TOTAL length is:
# $$
# \text{Length} = 2 \cdot t_{1-\alpha/2} \cdot s \sqrt{1 + x_0^T (X^T X)^{-1} x_0}.
# $$
# So still $ 2\cdot t(18)_{0.975}$ then we should pick an option that instead of $\sqrt{1 + x_0^T (X^T X)^{-1} x_0}$ we have to use:
# $$
# \text{SE} \sqrt{(\text{Std Mean Pred})^2 + s^2}
# $$
# Here $s=0.098$ and Std Mean Pred $0.0230$ so $0.0230^2$ and $0.098^2 = 0.009604$.
#
# **This is closest to option 4.**

# %% [markdown]
# ### **Question 3.3**
#
# <img src="SymPyBilleder/2025-11-17-11-06-31.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# If Cook's D is very low then then the observation has little influence on the overall regression results and observation 20 has lowest D.
#
# **The answer is, therefore, option 5.**
#
# ONE must also look at absolute value of DFFITS and observation 20 has the lowest absolute DFFITS.

# %% [markdown]
# ### **Quesiton 3.4**
#
# <img src="SymPyBilleder/2025-11-17-11-38-24.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# So RStudent should be above $2$ to be extreme and for leverage being extreme it should be above $h > 0.20$. Only observation 9 has RStudent above $2$ but leverage $h$ hat diag is $0.1591$ so no observations have extreme in both.
#
# **The answer is, therefore, topion 1.**

# %% [markdown]
# ### **Question 3.5**
#
# <img src="SymPyBilleder/2025-11-17-12-06-41.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# This is observation 9 because it has the highest student residual. "Student Residual describes the standardized form of the residuals. It's a measure of how much each data point's observed value differs from the predicted value, taking into account the estimated standard error of the residuals." SO student residual is the cleanest indicator of how bad something is since large absolute values mean the prediction was way off relative to expected noise.
#
# **The answer is, therefore, option 3.**

# %% [markdown]
# ### **Question 4.1**
#
# <img src="SymPyBilleder/2025-11-17-10-34-21.png" width="550">
#
# <img src="SymPyBilleder/2025-11-17-10-34-31.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# For lnhp and wt there are some patterns, some systematic structures for the residuals in the diagnostic plots. This indicates that a more complex model might need. So, adding quadratic terms for these two predictors could be a solution.
#
# **The answer is 5.**

# %% [markdown]
# ### **Question 4.2**
#
# <img src="SymPyBilleder/2025-11-17-12-33-55.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# I can count to 5 that fall outside the boundaries.
#
# **The answer is, therefore, option 2.**

# %% [markdown]
# ### **Question 4.3**
#
# <img src="SymPyBilleder/2025-11-17-12-35-21.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# WE find something on the form on:
# $$
# F=\frac{(SSE_{\text{reduced}}-SSE_{\text{full}})/q}{SSE_{\text{full}}/(n-p_{\text{full}})}
# $$
# Here $q$ is number of restrictions. So in our case, our full model has 'wt lnhp sqsp sqhp' now reduced to just 'sqsp' ans 'sqhp', so $k=2$ and $n$ is $82$ so with $5$ parameters $4$ plus intercept:
# $$
# 82 - 5 = 77
# $$
# This restricts us to the last three options. Moreover, our $SSE_{\text{reduced}}$ is $0.56239$, and our $SSE_{\text{full}}$ is $0.44873$ from calculating:
# $$
# \text{SSE}_{\text{full}} = \text{SST}\times(1-R^2)
# = 7.50390\times(1-0.9402)
# = 7.50390\times 0.0598
# \approx 0.44873
# $$
# WHERE SST IS "Total corrected sum of squares (SST)" while $0.9402$ is the $R^2$ value from the full model summary output.
#
# **The answer is, therefore, option 5.**

# %% [markdown]
# ### **Question 4.4**
#
# <img src="SymPyBilleder/2025-11-17-12-54-30.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# It is usally written as:
# $$
# F(q, n - p_{\text{full}})
# $$
# So:
# $$
# F(2, 77)
# $$
# **The answer is, therefore, option 5.**

# %% [markdown]
# ### **Question 5.1**
#
# <img src="SymPyBilleder/2025-11-17-12-58-58.png" width="550">
#
# <img src="SymPyBilleder/2025-11-17-12-59-08.png" width="550">
#
# <img src="SymPyBilleder/2025-11-17-12-59-16.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# If we look at the matrix "Eigenvalues of the Correlation Matrix", then we can see that we must pick at least 4 components in order to explain more than $80\%$ of the variance.
#
# **The answer is, therefore, option 3.**

# %% [markdown]
# ### **Question 5.2**
#
# <img src="SymPyBilleder/2025-11-17-13-01-49.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# If we test if the last $k-m$ eigenvalues are equal we look at week 3 slides:
# $$
# df = \frac{1}{2}(k-m+2)(k-m-1)_{1-\alpha}
# $$
# Here, we have $3$ eigenvalues to test and we originally have $9$ so $k=9$ and $m=6$ so:
# $$
# = \frac{1}{2}(9-6+2(9-6-1)) = \frac{1}{2}(5 \cdot 2) = 5
# $$
# **The answer is, therefore, option 1.**

# %% [markdown]
# ### **Question 5.3**
#
# <img src="SymPyBilleder/2025-11-17-13-02-07.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# First we recall the table:
#
# <img src="SymPyBilleder/2025-11-17-12-59-08.png" width="550">

# %% [markdown]
# From this, we can conclude that A is NOT factor 1, because it is lying down and not upright growth and it is relatively big in plant height, and A should be "small". The first factor seems to be B because it has early bloming with large $x5$ value, and it also has large values in $x6$-$x9$ fitting with good height and lots of seed.
#
# **The answer is, therefore, option 5.**

# %% [markdown]
# ### **Question 5.4**
#
# <img src="SymPyBilleder/2025-11-17-13-02-23.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# We can read this directly from the output where the factor 1 variance explained is $2.7197$ so to get the fraction or proportion we just divide with $9$, the total number of variables.
#
# **The answer is, therefore, option 4.**

# %% [markdown]
# ### **Question 5.5**
#
# <img src="SymPyBilleder/2025-11-17-13-02-48.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# To find the variation of a variale by a rotated factor is just to take the loading value and square it. We see that it is $0.79486$.
#
# **The answer is, therefore, option 4.**

# %% [markdown]
# ### **Question 6.1**
#
# <img src="SymPyBilleder/2025-11-17-13-03-02.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# The general form is:
# $$
# U(s, r, n-k)
# $$
# Where $s$ is number of response dimensions, $r$ is number of restrictions, and $n-k$ is the degrees of freedom for error. In our case, we have $2$ response dimensions, because we look at $6$ and $7$ stamp times. Then the output also shows DF within classes with is $54$, this is also from $57-3$ as the $57$ observations minus $3$ groups.
# $$
# U(2, 2, 57-3) = U(2, 2, 54)
# $$
#
# **The answer is, therefore, option 1.**

# %% [markdown]
# ### **Question 6.2**
#
# <img src="SymPyBilleder/2025-11-17-13-03-19.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# We look at error SSCP matrix and see $0.0349065$ and we have to divide with DF within classes which is $54$.
#
# **The answer is, therefore, option 4 (CHAT GOT IT WRONG gg).**

# %% [markdown]
# ### **Question 6.3**
#
# <img src="SymPyBilleder/2025-11-17-13-03-35.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# We use the hotellings formula:
# $$
# T^2=\frac{n_X n_Y}{n_X+n_Y}(\bar X-\bar Y)^\top S^{-1}(\bar X-\bar Y),
# $$
# And test statistic is:
# $$
# \frac{n+m-p-1}{(n+m-2)p}T^2 \sim F(p, n+m-p-1)
# $$
# We can read $(\bar X-\bar Y)^\top S^{-1}(\bar X-\bar Y)$ from the output and we see that it is $0.16700$, which is the error aka "Generalized Squared Distance".
#
# From the table below:
#
# <img src="SymPyBilleder/2025-11-17-15-47-10.png" width="550">
#
# WE can also see that $n_x = 16$ and $n_y=21$ and we have $p=2$ variables.
#
# **The answer is option 1 (CHAT GOT IT WRONG).**

# %% [markdown]
# ### **Question 6.4**
#
# <img src="SymPyBilleder/2025-11-17-13-03-52.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# From above we see how $F(p, n+m-p-1)$ so:
# $$
# F(2, 16+21-2-1) = F(2, 34)
# $$
# **The answer is, therefore, option 3.**

# %% [markdown]
# ### **Question 6.5**
#
# <img src="SymPyBilleder/2025-11-17-13-04-07.png" width="550">

# %% [markdown]
# **Answer:**

# %% [markdown]
# Use the SAS discriminant output ri versus wi. The two linear scores are:
# $$
# S_{ri}(x)= -748.96607 + 1125\cdot rs6 + 346.41638\cdot rs7
# $$
# $$
# S_{wi}(x)= -754.69084 + 1098\cdot rs6 + 378.60181\cdot rs7
# $$
# Classify as RI when $S_{ri}(x)-S_{wi}(x)>0$. So:
# $$
# S_{ri}-S_{wi} = (1125-1098),rs6 + (346.41638-378.60181),rs7 +(-748.96607-(-754.69084))
# $$
# $$
# = 27\cdot rs6 -32.18543\cdot rs7 + 5.72477
# $$
#
# Rewrite as (27\cdot rs6 + (-32.18543)\cdot rs7 > -5.72477). Rounded to integers:
# $$
# a = 27
# $$
# $$
# b = -32
# $$
# $$
# c = -6
# $$
# **The answer is, therefore, option 1.**
