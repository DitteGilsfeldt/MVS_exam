# %% [markdown]
# # **Multivariate statistics**
# # Index file
#
# [Course book](02409_eBook.pdf)

# %% [markdown]
# ## **Helper notebooks**
#
# [Equations and notes](formelsamling_MS.ipynb)
#
# [R code cheat sheet](MS_R_cheat_sheet.ipynb)

# %% [markdown]
# ## **Weekly slides**

# %% [markdown]
# [Week 1 slide A](slides/slide_A.pdf)\
# Introductory examples on multivariate statistics: The Challenger Disaster and logistic regression. Repetition of basic concepts on random variables. Introductory examples on 2-dimensional distributions. The 2-dimensional normal distribution (Reading: Book chapter 1.1, 1.2.1-1.2.3 and 1.3).
#
# [Week 2 slide B](slides/slide_B.pdf)\
# Conditional distribution in two-dimensional and multidimensional Gaussian distributions illustrated by example on height & weight measurements from 25000 individuals. Estimation of parameters. Correlation, partial correlation and multiple correlation (Book chapter 1.1-1.3).
#
# [Week 3 slide C](slides/slide_C.pdf)\
# Conditional distribution in two-dimensional and multidimensional Gaussian distributions illustrated by example on height & weight measurements from 25000 individuals. Estimation of parameters. Correlation, partial correlation and multiple correlation (Book chapter 1.1-1.3).
#
# [Week 4 slide D](slides/slide_D.pdf)\
# Principal Component Analysis revisited. Factor analysis. Principal factor solution. Factor rotation. Computation of factor scores (Book sections 6.1, 6).
#
# [Week 5 slide E](slides/slide_E.pdf)\
# Canonical Correlation Analysis. Illustration of concepts and methods through examples. The elements of discrimination and classification. Prior and posterior distributions. Bayes and minimax solutions. Introduction to the multivariate normal case (Book section 6).
#
# [Week 6 slide F](slides/slide_F.pdf)\
# Discrimination and classification. Bayes and minimax solutions. The multivariate normal case and Mahalanobis' distance. Linear versus quadratic discriminant analysis. Estimation of misclassification rates: calibration and test data sets, plug in estimates, cross validation. Canonical discriminant analysis (Book chapter 5).
#
# [Week 7 slide G](slides/slide_G.pdf)\
# Discriminant analysis and Canonical Discriminant Functions (CDF) revisited. Introduction to the General Linear Model (GLM). Estimation. (Chapter 5 ections 2.1.1, 2.1.2).
#
# [Week 8 slide H](slides/slide_H.pdf)\
# The General Linear Model. Estimation, confidence-and prediction intervals, tests. Book chapter 2 (except section 2.1.3, 2.1.4, and 2.1.5).
#
# [Week 9 slide I](slides/slide_I.pdf)\
# Model specification in glm. Regression analysis, model selection, influence statistics and diagnostics (Book sections 2.2.2, 3.1, 3).
#
# [Week 10 slide J](slides/slide_J.pdf)\
# Glm and Regression Analysis revisited. Selection of best regression. Hotellings test statistics. The Multivariate General Linear Model (Book sections 3.1, 3.2, 3.4, 3.5.1, 3.5.2, 4).
#
# [Week 11 slide K](slides/slide_K.pdf)\
# The Multivariate General Linear Model and Multivariate Analyses of Variance (MANOVA) (Book sections 4.1, 4.2, 4).
#
# [Week 12 slide L](slides/slide_L.pdf)\
# Multivariate General Linear Model revisited, Repeated Measurement Model (Book chapter 4, 2.3).

# %% [markdown]
# ## **Weekly notebooks (WITH R code)**

# %% [markdown]
# [Week 1](weekly_notebooks/week_1_MS.ipynb)
# > 1.1 is brush up on linear algebra and properties of variance and correlation matrices\
# > 1.2 (exam 2013, problem 2) is calculation of multivariate mean, variance matrices and conditional mean\
# > E1 is exercise on the impact of correlation.
#
# [Week 2](weekly_notebooks/week_2_MS.ipynb)
#
# > 1.3 is a ‘pen and paper’ exercise to explore
# multiple and partial correlation\
# > 2.4 is a real data case on hay production, that
# explores partial correlation.\
# > 2.5 is a real data case on fitness data.
#
# [Week 3](weekly_notebooks/week_3_MS.ipynb)
# > 7.1 is principal Component Analysis on Olympic data and interpretation, number of components\
# > 7.2 principal Component Analysis on the ’Fitness’ dataset and interpretation, number of components, conditioning on variables\
# > 7.3 principal Component Analysis on Beef characterization and interpretation of PCA\
# > 7.4 is PCA by hand and interpretation
#
# [Week 4](weekly_notebooks/week_4_MS.ipynb)
#
# > Exam 2011, problem 2, PCA and factor analysis\
# > 7.5 is ”Pen & Paper” on factor analysis\
# > 7.7 R on factor analysis\
# > Exam 2013, problem 1, factor analysis
#
# [Week 5](weekly_notebooks/week_5_MS.ipynb)
# > Exam 2011, problem 4 CCA, pen and paper\
# > Exam 2011, problem 5 on CCA, SAS-outputs\
# > 7.6 is on canonical Correlation Analysis on Beef Characterization and physical and chemical measurements vs. tasting panel
#
# [Week 6](weekly_notebooks/week_6_MS.ipynb)
#
# > 6.1 general introduction to Linear Discriminant Analysis\
# > 6.2 test of means, test for further information, classification\
# > 6.3 test of means, classification
#
# [Week 7](weekly_notebooks/week_7_MS.ipynb)
#
# > 6.4 is ”Pen & paper” on CDF\
# > Exam 2011 Q. 3.3-3.6 on Classification\
# > Exam 2009 Problem 1 on Classification\
# > 3.1 and 3.2 on GLM
#
# [Week 8](weekly_notebooks/week_8_MS.ipynb)
#
# > 3.3 on GLM\
# > 3.4 on GLM\
# > 3.6 on GLM. Compare what the Anova() function from the car package does, to the drop1() function. Data can alternatively be accessed from the dataset Cars93 from the MASS package: library(MASS); data(Cars93)
#
# [Week 9](weekly_notebooks/week_9_MS.ipynb)
#
# > Exam 2009, problem 3 (testing)\
# > Exam 2012 problems 5.1-5.4 on estimation\
# > Brain Exercise, including extra questions on model selection\
# > Process Exercise on first look at interactions
#
# [Week 10](weekly_notebooks/week_10_MS.ipynb)
#
# > Exam 2007 problem 8\
# > Exam 2008 problem 3 (disregard pin 3.7)\
# > 4.3 (disregard task 5)\
# > 5.1
#
# [Week 11](weekly_notebooks/week_11_MS.ipynb)
#
# > Nothing to see here
#
# [Week 12](weekly_notebooks/week_12_MS.ipynb)
#
# > Nothing to see here

# %% [markdown]
# ## **Previous exam questions organized in "problem theme"**

# %% [markdown]
# ### **Multivariate Random Variables & Covariance Structure**
#
# Covariance between two variables, consider random variable

# %% [markdown]
# Fraction of variace of one variable explained by another variable, or this variable explains the following fraction of the variance in another variable, fraction of variance in one variable explained by two other variables TOGETHER
# > Exam 2022 Q3.1\
# > Exam 2023 Q7.3\
# > Exam 2021 Q1.3
#
# Usual test-statistic test statistic for correlation between two variables being different from zero:
# > Exam 2021 Q4.1\
# > Exam 2023 Q3.2
#
# Confidence interval for correlation coefficient between two variables
# > Exam 2023 Q3.3
#
# For dispersion matrix of a variable to be INVERTIBLE then rho $\rho$ must be in what interval
# > Exam 2023 Q7.1
#
# Find the first squared canonical correlation between two sets of variables
# > Exam 2023 Q7.2
#
# Find conditional mean
# > Exam 2023 Q7.4\
# > Exam 2021 Q6.2, Q6.3, Q6.4\
# > Exam 2020 Q5.5, Q5.6
#
# Find conditional dispersion
# > Exam 2023 Q7.5
#
# Squared partial correlation
# > Exam 2023 Q7.6\
# > Exam 2021 Q6.5, Q6.6
#
# Squared multiple correlation
# > Exam 2023 Q7.7\
# > Exam 2021 Q6.7\
# > Exam 2020 Q5.7
#
# Squared correlation between two variables
# > Exam 2021 Q6.1
#
#
# Three-dimensional multivariate normal distribution with known covariance matrix
# > Exam 2021 Q6.1
#
# Observation with largest impact:
# > Exam 2021 Q2.4
#
# For which values of rho gives proper dispersion matrix, semi-definite positive
# > Exam 2020 Q5.1
#
# Find variance of linear combination of variables
# > Exam 2020 Q5.2
#
# Find covariance of linear combination of variables
# > Exam 2020 Q5.3, Q5.4
#
# For positive rho, maximum squared correlation between any linear combination
# > Exam 2020 Q5.8

# %% [markdown]
# ### **Principal Component Analysis (PCA)**

# %% [markdown]
# Use what matrix if we were to perform PCA (principle component analysis)?
# > Exam 2022 Q3.1
#
# PCA on matrix of the data, number of components to account for at least some percentage of variance in data
# > Exam 2021 Q4.2
#
# Consider PCA on correlation matrix, usual test-statistic for last two eigenvalues being equal
# > Exam 2021 Q4.3

# %% [markdown]
# ### **Factor Analysis**
#
# Factor analysis with VARIMAX, principle factor solution

# %% [markdown]
# How many factors or components to include to retain a number of variance
# > Exam 2023 Q5.1
#
# Consider how many factors to retain, consider correlation matrix, test-statistic for the LAST x number of eigenvalues of correlation matrix being equal against all alternatives
# > Exam 2022 Q3.2
#
# Factor analysis with rotated VARIMAX rotated factors, VARIMAX factors have following description, a VARIMAX factor can be interpreted as
# > Exam 2022 Q3.3
# > Exam 2023 Q5.2
#
# Interpretaion of rotated factors, interpretation of factors to rotated factors
# > Exam 2021 Q4.5\
# > Exam 2020 Q1.8
#
# Uniqueness of a variable with VARIMAX rotated factors
# > Exam 2022 Q3.4
#
# VARIMAX rotated factors together explain the following fraction of variance in a variable
# > Exam 2022 Q3.5
#
# ROTATAED factor explains following fraction of variance in a VARIABLE
# > Exam 2020 Q1.6
#
# Unrotated factor x and y combined explains following fraction of variance in a variable
# > Exam 2021 Q4.4
#
# Unrotated factor explains which fraction of variance in DATA
# > Exam 2020 Q1.5
#
# If performed principal component analysis (PCA) on standardized data, first x components would describe the following fraction of variance in the data
# > Exam 2020 Q1.4
#
# Test correlation between two variables is zero against all alternatives, the p-value fo test, range, falls in what range
# > Exam 2020 Q1.1
#
# Partial correlation between two variables when conditioned on a third variable
# > Exam 2020 Q1.2
#
# Confidence interval of the correlation between two variables
# > Exam 2020 Q1.3
#
# Uniqueness of variable using rotated factor model
# > Exam 2020 Q1.7

# %% [markdown]
# ### **Canonical Correlation Analysis (CCA)**
#
# Study relationship between one set of variables and another set of variables

# %% [markdown]
# Number of significant canonical correlations at a significance level
# > Exam 2022 Q4.1
#
# First set of canonical variable, find meaning of variables
# > Exam 2022 Q4.2
#
# Based on canonical correlation analysis (CCA), find interpretation of variables
# > Exam 2022 Q4.3
#
# How much variation in the first canonical variable is explained by the first set of another canonical variable, how much a set of canonical variates explain fraction of variation, two datasets (data sets)
# > Exam 2022 Q7.1\
# > Exam 2021 Q1.1
#
# Test if two datasets are independent against all alternatives, find usual test statistic (test-statistic), follows what distribution if null hypothesis is true
# > Exam 2022 Q7.2
#
# If mean is unknown, find minimum number of observations needed to get full rank estimate
# > Exam 2022 Q7.3
#
# Eigenvalues of E^-1H are significantly different form zero at 5% significance level
# > Exam 2021 Q1.2
#
# Interpretation using appropriate correlations
# > Exam 2021 Q1.4

# %% [markdown]
# ### **Discriminant Analysis & Classification**
#
# LDA, linear discriminant analysis, discriminate between different groups

# %% [markdown]
# Equal priors and losses, find number of misclassifications with equal prior probabilities and equal losses
# > Exam 2023 Q2.1\
# > Exam 2022 Q2.1
#
# Number of resubstitution misclassifications, going from QDA to LDA, quadratic discriminant analysis to linear discriminant analysis, find number of misclassifications, increased misclassifications when going from QDA to LDA
# > Exam 2021 3.1
#
# Test if variables can be **OMITTED**, use usal test-statistic, find **p-value (p value)** in range, find if variables are contributed or can **be discarded**, usual test for hypothesis that two groups **do NOT contribue**
# > Exam 2023 Q2.2\
# > Exam 2022 Q2.4
#
# Consider full model, change priors (NOT equal priors anymore), find squared generalization distance from mean of a group to itself:
# > Exam 2023 Q2.3
#
# Mahalanobis distance, find to groups that are hardest to discriminate between
# > Exam 2022 Q2.2
#
# Most different classes via Mhalanobis distance BASED on pooled dispersion matrix
# > Exam 2021 Q3.2
#
# Find if there is significant distance between two groups, Hotellings T2 test for difference in means, find p-value:
# > Exam 2022 Q2.3\
# > Exam 2021 Q3.3
#
# LDA, test if variables contribute to discrimination between groups, usual test statistic
# > Exam 2021 Q3.4
#
# QDA, going from LDA to QDA, resubsitution specificity is increased by
# > Exam 2021 Q3.5
#
# Full model using all variables, reduced using only some variables, find number of misclassifications in full model
# > Exam 2020 Q4.3
#
# Test if two variables contribute to discrimination between groups using LDA (linear discriminant analysis), find usual test statistic
# > Exam 2020 Q4.4
#
# Consider reduced model, find class sensitivity
# > Exam 2020 Q4.5
#
# Only consider two groups, find usual test-statistic for reduced model in mean values
# > Exam 2020 Q4.6

# %% [markdown]
# ### **The General Linear Model (GLM)**
#
# Random variables, the problem often gives matrices and formulas - no more R code I guess

# %% [markdown]
# Ordinary least squares estimate of estimator
# > Exam 2023 Q6.1\
# > Exam 2022 Q5.1, Q5.3
#
# Variance of least squares estimator
# > Exam 2023 Q6.2
# > Exam 2022 Q5.2
#
# Correlation, correlation between two estimators
# > Exam 2023 Q6.3
# > Exam 2022 Q5.4, Q5.6
#
# Change experimental design so two parameters can be uniquely estimated such their estimates becomes UNCORRELATED, find the layout
# > Exam 2023 Q6.4
#
# Asumme a parameter $= 0$ (= 0), the ordinary least squares (OLS) under this assumption is
# > Exam 2022 Q5.5

# %% [markdown]
# ### **Regression Analysis**
#
# Simple and multiple linear regression, interpretation of coefficients, residual analysis, influence diagnostics (Cook’s distance, leverage), partial & semi-partial correlations, polynomial regression, variable selection methods (forward, backward, stepwise) and regularization ridge and lasso).

# %% [markdown]
# Find $R^2$ (R^2, R2, R square) of the model
# > Exam 2023 Q1.1
#
# Highest $R^2$ (R^2, R2, R square) by including which variables
# > Exam 2021 Q2.2
#
# Rstudent, absolute Rstudent above 2, influential observations, both RStudent above 2 and leverage above 0.102
# > Exam 2023 Q1.2, Q1.3
#
# Observation with LOWEST LEVERAGE
# > Exam 2021 Q2.3
#
# Observation with HIGHEST LEVERAGE
# > Exam 2020 Q2.2
#
# Cook's D, Cooks distnce values, what observaiton are most influential, what would change parameter vector the MOST if REMOVED, most influential observation by Cook's (Cooks D) D and DFFITs, given design matrix find observation with largest POTENTIAL to influence esimates of the model parameters, observation that if deleted will lead to largest overall change in parameter estimates
# > Exam 2023 Q1.4\
# > Exam 2022 Q4.4, Q4.5\
# > Exam 2020 Q2.4
#
# Number of observations with Cook's D (Cokks D) larger than a threshold
# > Exam 2021 Q2.5
#
# VIF and tolerance, VIF larger than 10 and tolerance below 0.1, consinder if we have problems with multicollinearity
# > Exam 2023 Q1.5
# > Exam 2022 Q4.3
#
# Variable with LARGEST tolerance:
# > Exam 2021 Q2.1
#
# P-value for usual test for effect falls in waht interval
# > Exam 2021 Q5.1
#
# Matrix Q1 notation
# > Exam 2021 Q5.2
#
# Usual test statistic for effect if only considering some variables
# > Exam 2021 Q5.3
#
# Backwards elimination (remove lowest F-value or highest p-value), backwards elimination based on F-value, first variable to be ELIMINATED when performing backwards elimination
# > Exam 2023 Q1.6\
# > Exam 2022 Q4.6\
# > Exam 2020 Q2.1
#
# Forward selection (add or include highest F-value or lowest p-value)
# > Exam 2023 Q1.7
#
# Usual test statistic, testing simpler model, testing full model against reduced model, DF, degree of freedom
# > Exam 2023 Q1.8
#
# Test statistic for testing hypothesis that fraction of VARIATION of variable explained by model is ZERO, find the distribution
# > Exam 2022 Q4.2
# f
# Given regression model, we explain the following fraction of VARIATION, in a variable
# > Exam 2022 Q4.1
#
# Two parameter estimates with numerically largest covariance
# > Exam 2021 Q2.6
#
# Confidence interval for expected value of observation number x
# > Exam 2020 Q2.3
#
# Using only x of the independent variables, the best model as measrued by R-square (R^2, R2, R square)
# > Exam 2020 Q2.5

# %% [markdown]
# ### **ANOVA / ANCOVA / MANOVA**
#
# Consider differences between things (products) by different groups (manufacturers) by means of a model, one-way MANOVA.

# %% [markdown]
# Test same mean against all alternatives, Wilks Lambda test
# > Exam 2022 Q1.1
#
# Using only two variables to test for effect, usual test-statistic (Wilk's lambda or Wilks lambda) Anderson's U (Andersons U)
# > Exam 2020 Q4.1
#
# Find largest difference between group in a variable
# > Exam 2022 Q1.2
#
# Null hypothesis that all groups have same mean against all alternatives, se iff null hypothesis (null-hypothesis) is true, find usual test statistic, U-test statistic, significance level, lowest number of observations for test to be significant
# > Exam 2022 Q1.3, Q1.4
#
# Test model 1 if parameter for a variable is significantly different from zero against all alternatives, find p-value for this test
# > Exam 2020 Q3.1
#
# Test in model 1 if parameter for a variable is significantly different from zero against all alternatives, find usual test statistic, under null-hypothesis follows what distribution
# > Exam 2020 Q3.2
#
# Test model 1 through x starting from 1, sequential test of models, find simplest model we accept
# > Exam 2020 Q3.3
#
# Variable with largest effect measured by F-value
# > Exam 2020 Q4.2

# %% [markdown]
# ## **Previous exam questions and solutions**
#
# Organized in teachers answers and original exam papers.
